# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:\projects\dataAnalytics\Data Analytics Real World Project -Python-20211101T131104Z-001\Data Analytics Real World Project -Python\IplDataAnalysis/deliveries.csv')
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
filtered = df['batsman']=='DA Warner'
df_warner=df[filtered]
df_warner.shape
# Out:
# (2902, 21)

# %%
df_warner['dismissal_kind'].value_counts()
# Out:
# caught               62
# bowled               21
# run out               8
# stumped               4
# lbw                   4
# caught and bowled     2
# hit wicket            1
# Name: dismissal_kind, dtype: int64

# %%
df_warner['dismissal_kind'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='dismissal_kind'>

# %%
len(df_warner[df_warner['batsman_runs']==4])
# Out:
# 401

# %%
def count(df,runs):
    return len(df_warner[df_warner['batsman_runs']==runs])*runs

# %%
count(df_warner,1)
# Out:
# 997

# %%
slices=[997,414,39,1604,960]
labels=[1,2,3,5,8]
plt.pie(slices,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d32ac24df0>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.0200956448131961, -0.4115882352948756, '5'),
#   Text(0.8038429148449225, -0.750890516822272, '8')],
#  [Text(0.4264169293674199, 0.4221002278474401, '24.8%'),
#   Text(-0.18523151829556675, 0.5706919349613407, '10.3%'),
#   Text(-0.3718342296325332, 0.4708920318646096, '1.0%'),
#   Text(-0.5564158062617433, -0.22450267379720487, '40.0%'),
#   Text(0.4384597717335941, -0.4095766455394211, '23.9%')])

# %%
slices=[997,414,39,1604,960]
labels=[1,2,3,5,8]
explode=[0,0,0,0.1,0]
plt.pie(slices,labels=labels,autopct='%1.1f%%',explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d32ac7fa60>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.1128316125234867, -0.44900534759440974, '5'),
#   Text(0.8038429148449225, -0.750890516822272, '8')],
#  [Text(0.4264169293674199, 0.4221002278474401, '24.8%'),
#   Text(-0.18523151829556675, 0.5706919349613407, '10.3%'),
#   Text(-0.3718342296325332, 0.4708920318646096, '1.0%'),
#   Text(-0.6491517739720338, -0.261919786096739, '40.0%'),
#   Text(0.4384597717335941, -0.4095766455394211, '23.9%')])

# %%
df = pd.read_csv('D:\projects\dataAnalytics\Data Analytics Real World Project -Python-20211101T131104Z-001\Data Analytics Real World Project -Python\IplDataAnalysis/matches.csv')
df.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot  4/7/2017                Gujarat Lions
# 3   4    2017     Indore  4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  4/8/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
filtered=df['team1'] == 'Sunrisers Hyderabad'
df_srh = df[filtered]
df_srh.shape
# Out:
# (46, 18)

# %%
df_srh['win_by_runs'].value_counts()
# Out:
# 0     22
# 22     3
# 15     3
# 5      2
# 4      2
# 35     1
# 34     1
# 32     1
# 30     1
# 26     1
# 23     1
# 20     1
# 85     1
# 16     1
# 11     1
# 8      1
# 7      1
# 6      1
# 48     1
# Name: win_by_runs, dtype: int64

# %%
df_srh['win_by_runs'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='win_by_runs'>

# %%
len(df_srh[df_srh['win_by_runs']==1])
# Out:
# 0

# %%
def count(df,runs):
    return len(df_srh[df_srh['win_by_runs']==runs])*runs

# %%
count(df_srh,10)
# Out:
# 0

# %%
count(df_srh,15)
# Out:
# 45

# %%
slices=[0,0,45]
labels=[1,2,3]
plt.pie(slices,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d32ac62940>,
# ...
#  [Text(1.1, 0.0, '1'),
#   Text(1.1, 0.0, '2'),
#   Text(-1.1, 1.3471114790620887e-16, '3')])

# %%
slices=[0,0,45]
labels=[1,2,3]
plt.pie(slices,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d32a14d940>,
# ...
#  [Text(1.1, 0.0, '1'),
#   Text(1.1, 0.0, '2'),
#   Text(-1.1, 1.3471114790620887e-16, '3')],
#  [Text(0.6, 0.0, '0.0%'),
#   Text(0.6, 0.0, '0.0%'),
#   Text(-0.6, 7.347880794884119e-17, '100.0%')])

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('D:\projects\dataAnalytics\Data Analytics Real World Project -Python-20211101T131104Z-001\Data Analytics Real World Project -Python\IplDataAnalysis/deliveries.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-42d45e0aa3fc> in <module>
# ----> 1 df = pd.read_csv('D:\projects\dataAnalytics\Data Analytics Real World Project -Python-20211101T131104Z-001\Data Analytics Real World Project -Python\IplDataAnalysis/deliveries.csv')
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
teams={
    'Royal Challengers Bangalore':'rcb', 'Sunrisers Hyderabad':'srh',
       'Rising Pune Supergiant':'pune', 'Mumbai Indians':'mi',
       'Kolkata Knight Riders':'kkr', 'Gujarat Lions':'lions', 'Kings XI Punjab':'kings',
       'Delhi Daredevils':'dd', 'Chennai Super Kings':'csk', 'Rajasthan Royals':'rr',
       'Deccan Chargers':'dc', 'Kochi Tuskers Kerala':'kerala', 'Pune Warriors':'pune',
       'Rising Pune Supergiants':'pune'
}

# %%
df['batting_team'] = df['batting_team'].map(teams)
df['bowling_team'] = df['bowling_team'].map(teams)

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          srh          rcb     1     1  DA Warner
# 1         1       1          srh          rcb     1     2  DA Warner
# 2         1       1          srh          rcb     1     3  DA Warner
# 3         1       1          srh          rcb     1     4  DA Warner
# 4         1       1          srh          rcb     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
# Out:
# match_id  inning  batting_team
# 1         1       srh             207
#           2       rcb             172
# 2         1       mi              184
#           2       pune            187
# 3         1       lions           183
#                                  ...
# 634       2       kkr             140
# 635       1       lions           162
#           2       srh             163
# 636       1       srh             208
#           2       rcb             200
# Name: total_runs, Length: 1284, dtype: int64

# %%
df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
# Out:
#       match_id  inning batting_team  total_runs
# 0            1       1          srh         207
# 1            1       2          rcb         172
# 2            2       1           mi         184
# 3            2       2         pune         187
# 4            3       1        lions         183
# ...        ...     ...          ...         ...
# 1279       634       2          kkr         140
# 1280       635       1        lions         162
# 1281       635       2          srh         163
# 1282       636       1          srh         208
# 1283       636       2          rcb         200
#
# [1284 rows x 4 columns]

# %% [markdown]
# runs = df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
# runs.drop('match_id',axis=1,inplace=True)
# runs

# %%
runs = df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
runs.drop('match_id',axis=1,inplace=True)
runs
# Out:
#       inning batting_team  total_runs
# 0          1          srh         207
# 1          2          rcb         172
# 2          1           mi         184
# 3          2         pune         187
# 4          1        lions         183
# ...      ...          ...         ...
# 1279       2          kkr         140
# 1280       1        lions         162
# 1281       2          srh         163
# 1282       1          srh         208
# 1283       2          rcb         200
#
# [1284 rows x 3 columns]

# %%
innings1=runs[runs['inning']==1]
innings2=runs[runs['inning']==2]

# %%
sns.boxplot(x='batting_team',y='total_runs',data=innings1)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
sns.boxplot(x='batting_team',y='total_runs',data=innings2)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
high_scores=df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
high_scores
# Out:
#       match_id  inning batting_team  total_runs
# 0            1       1          srh         207
# 1            1       2          rcb         172
# 2            2       1           mi         184
# 3            2       2         pune         187
# 4            3       1        lions         183
# ...        ...     ...          ...         ...
# 1279       634       2          kkr         140
# 1280       635       1        lions         162
# 1281       635       2          srh         163
# 1282       636       1          srh         208
# 1283       636       2          rcb         200
#
# [1284 rows x 4 columns]

# %%
scoresgt_200=high_scores[high_scores['total_runs']>=200]
scoresgt_200
# Out:
#       match_id  inning batting_team  total_runs
# 0            1       1          srh         207
# 16           9       1           dd         205
# 38          20       1          rcb         213
# 62          32       1          srh         207
# 72          36       1          srh         209
# ...        ...     ...          ...         ...
# 1250       620       1          rcb         248
# 1256       623       1           mi         206
# 1262       626       1          rcb         211
# 1282       636       1          srh         208
# 1283       636       2          rcb         200
#
# [67 rows x 4 columns]

# %%
sns.countplot(scoresgt_200['batting_team'])
# Out:
# C:\Users\KPL3KOR\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='batting_team', ylabel='count'>

# %%
sns.countplot(scoresgt_200['total_runs'])
# Out:
# C:\Users\KPL3KOR\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_runs', ylabel='count'>

# %%
df.groupby('batsman')['ball'].count()
# Out:
# batsman
# A Ashish Reddy     196
# A Chandila           7
# A Chopra            75
# A Choudhary         20
# A Flintoff          57
#                   ...
# YV Takawale        183
# Yashpal Singh       67
# Younis Khan          7
# Yuvraj Singh      2050
# Z Khan             141
# Name: ball, Length: 461, dtype: int64

# %%
df.groupby('batsman')['ball'].count().reset_index()
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
runs=df.groupby('batsman')['ball'].sum().reset_index()
runs
# Out:
#             batsman  ball
# 0    A Ashish Reddy   720
# 1        A Chandila    23
# 2          A Chopra   273
# 3       A Choudhary    71
# 4        A Flintoff   203
# ..              ...   ...
# 456     YV Takawale   695
# 457   Yashpal Singh   250
# 458     Younis Khan    25
# 459    Yuvraj Singh  7599
# 460          Z Khan   525
#
# [461 rows x 2 columns]

# %%
fours =df[df['batsman_runs']==4]
fours
# Out:
#         match_id  inning                 batting_team  \
# 2              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 30             1       1          Sunrisers Hyderabad
# 32             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150403       636       2  Royal Challengers Bangalore
# 150407       636       2  Royal Challengers Bangalore
# 150418       636       2  Royal Challengers Bangalore
# 150447       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman  \
# 2       Royal Challengers Bangalore     1     3      DA Warner
# 8       Royal Challengers Bangalore     2     2      DA Warner
# 13      Royal Challengers Bangalore     2     7   MC Henriques
# ...

# %%
runs_4=fours.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy            16
# 1          A Chopra             7
# 2       A Choudhary             1
# 3        A Flintoff             5
# 4          A Kumble             3
# ..              ...           ...
# 363       YK Pathan           240
# 364     YV Takawale            26
# 365   Yashpal Singh             5
# 366    Yuvraj Singh           205
# 367          Z Khan            11
#
# [368 rows x 2 columns]

# %%
runs_4.columns=['batsman','noOfFours']
runs_4
# Out:
#             batsman  noOfFours
# 0    A Ashish Reddy         16
# 1          A Chopra          7
# 2       A Choudhary          1
# 3        A Flintoff          5
# 4          A Kumble          3
# ..              ...        ...
# 363       YK Pathan        240
# 364     YV Takawale         26
# 365   Yashpal Singh          5
# 366    Yuvraj Singh        205
# 367          Z Khan         11
#
# [368 rows x 2 columns]

# %%
sixes =df[df['batsman_runs']==4]
runs_6=sixes.groupby('batsman')['batsman_runs'].count().reset_index()
runs_6.columns=['batsman','noOfSixes']
runs_6
# Out:
#             batsman  noOfSixes
# 0    A Ashish Reddy         16
# 1          A Chopra          7
# 2       A Choudhary          1
# 3        A Flintoff          5
# 4          A Kumble          3
# ..              ...        ...
# 363       YK Pathan        240
# 364     YV Takawale         26
# 365   Yashpal Singh          5
# 366    Yuvraj Singh        205
# 367          Z Khan         11
#
# [368 rows x 2 columns]

# %%
balls = df.groupby('batsman')['ball'].count().reset_index()
balls
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
player=pd.concat([runs,balls.iloc[:,1],runs_4.iloc[:,1],sixes.iloc[:,1]],axis=1)
player
# Out:
#                batsman   ball   ball  noOfFours  inning
# 0       A Ashish Reddy  720.0  196.0       16.0     NaN
# 1           A Chandila   23.0    7.0        7.0     NaN
# 2             A Chopra  273.0   75.0        1.0     1.0
# 3          A Choudhary   71.0   20.0        5.0     NaN
# 4           A Flintoff  203.0   57.0        3.0     NaN
# ...                ...    ...    ...        ...     ...
# 150403             NaN    NaN    NaN        NaN     2.0
# 150407             NaN    NaN    NaN        NaN     2.0
# 150418             NaN    NaN    NaN        NaN     2.0
# 150447             NaN    NaN    NaN        NaN     2.0
# 150459             NaN    NaN    NaN        NaN     2.0
#
# [17436 rows x 5 columns]

# %%
player.fillna(0,inplace=True)
player
# Out:
#                batsman   ball   ball  noOfFours  inning
# 0       A Ashish Reddy  720.0  196.0       16.0     0.0
# 1           A Chandila   23.0    7.0        7.0     0.0
# 2             A Chopra  273.0   75.0        1.0     1.0
# 3          A Choudhary   71.0   20.0        5.0     0.0
# 4           A Flintoff  203.0   57.0        3.0     0.0
# ...                ...    ...    ...        ...     ...
# 150403               0    0.0    0.0        0.0     2.0
# 150407               0    0.0    0.0        0.0     2.0
# 150418               0    0.0    0.0        0.0     2.0
# 150447               0    0.0    0.0        0.0     2.0
# 150459               0    0.0    0.0        0.0     2.0
#
# [17436 rows x 5 columns]

# %%
player['inning']=(player['ball']/player['ball'])*100
player
# Out:
#                batsman   ball   ball  noOfFours  inning
# 0       A Ashish Reddy  720.0  196.0       16.0   100.0
# 1           A Chandila   23.0    7.0        7.0   100.0
# 2             A Chopra  273.0   75.0        1.0   100.0
# 3          A Choudhary   71.0   20.0        5.0   100.0
# 4           A Flintoff  203.0   57.0        3.0   100.0
# ...                ...    ...    ...        ...     ...
# 150403               0    0.0    0.0        0.0     NaN
# 150407               0    0.0    0.0        0.0     NaN
# 150418               0    0.0    0.0        0.0     NaN
# 150447               0    0.0    0.0        0.0     NaN
# 150459               0    0.0    0.0        0.0     NaN
#
# [17436 rows x 5 columns]

# %%
grp=df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()
grp
# Out:
#       match_id       batsman                 batting_team  batsman_runs
# 0            1   A Choudhary  Royal Challengers Bangalore             6
# 1            1   BCJ Cutting          Sunrisers Hyderabad            16
# 2            1      CH Gayle  Royal Challengers Bangalore            32
# 3            1     DA Warner          Sunrisers Hyderabad            14
# 4            1      DJ Hooda          Sunrisers Hyderabad            16
# ...        ...           ...                          ...           ...
# 9510       636     SR Watson  Royal Challengers Bangalore            11
# 9511       636     STR Binny  Royal Challengers Bangalore             9
# 9512       636   Sachin Baby  Royal Challengers Bangalore            18
# 9513       636       V Kohli  Royal Challengers Bangalore            54
# 9514       636  Yuvraj Singh          Sunrisers Hyderabad            38
#
# [9515 rows x 4 columns]

# %%
grp.groupby('batsman')['batsman_runs'].max()
# Out:
# batsman
# A Ashish Reddy    36
# A Chandila         4
# A Chopra          24
# A Choudhary       15
# A Flintoff        24
#                   ..
# YV Takawale       45
# Yashpal Singh     20
# Younis Khan        3
# Yuvraj Singh      83
# Z Khan            23
# Name: batsman_runs, Length: 461, dtype: int64

# %%
max = grp.groupby('batsman')['batsman_runs'].max().reset_index()
max.columns=['batsman','max_runs']
max
# Out:
#             batsman  max_runs
# 0    A Ashish Reddy        36
# 1        A Chandila         4
# 2          A Chopra        24
# 3       A Choudhary        15
# 4        A Flintoff        24
# ..              ...       ...
# 456     YV Takawale        45
# 457   Yashpal Singh        20
# 458     Younis Khan         3
# 459    Yuvraj Singh        83
# 460          Z Khan        23
#
# [461 rows x 2 columns]

# %%
player1=pd.concat([player,max.iloc[:,1]],axis=1)
player1
# Out:
#                batsman   ball   ball  noOfFours  inning  max_runs
# 0       A Ashish Reddy  720.0  196.0       16.0   100.0      36.0
# 1           A Chandila   23.0    7.0        7.0   100.0       4.0
# 2             A Chopra  273.0   75.0        1.0   100.0      24.0
# 3          A Choudhary   71.0   20.0        5.0   100.0      15.0
# 4           A Flintoff  203.0   57.0        3.0   100.0      24.0
# ...                ...    ...    ...        ...     ...       ...
# 150403               0    0.0    0.0        0.0     NaN       NaN
# 150407               0    0.0    0.0        0.0     NaN       NaN
# 150418               0    0.0    0.0        0.0     NaN       NaN
# 150447               0    0.0    0.0        0.0     NaN       NaN
# 150459               0    0.0    0.0        0.0     NaN       NaN
#
# [17436 rows x 6 columns]

# %%
max_runs=df.groupby('batsman')['batsman_runs'].sum()
max_runs
# Out:
# batsman
# A Ashish Reddy     280
# A Chandila           4
# A Chopra            53
# A Choudhary         25
# A Flintoff          62
#                   ...
# YV Takawale        192
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2591
# Z Khan             117
# Name: batsman_runs, Length: 461, dtype: int64

# %%
max_runs=df.groupby('batsman')['batsman_runs'].sum()
max_runs.sort_values(ascending=False)[:10].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='batsman'>

# %%
df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index().sort_values(by='batsman_runs',ascending=False).head(15)
# Out:
#       match_id         batsman                 batting_team  batsman_runs
# 6200       411        CH Gayle  Royal Challengers Bangalore           175
# 900         60     BB McCullum        Kolkata Knight Riders           158
# 8426       562  AB de Villiers  Royal Challengers Bangalore           133
# 9257       620  AB de Villiers  Royal Challengers Bangalore           129
# 5585       372        CH Gayle  Royal Challengers Bangalore           128
# 3135       206         M Vijay          Chennai Super Kings           127
# 529         36       DA Warner          Sunrisers Hyderabad           126
# 7752       516        V Sehwag              Kings XI Punjab           122
# 3686       243     PC Valthaty              Kings XI Punjab           120
# 4223       279        V Sehwag             Delhi Daredevils           119
# 8358       557        CH Gayle  Royal Challengers Bangalore           117
# 1017        68       A Symonds              Deccan Chargers           117
# ...

# %%
df['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dismissal_kinds=['caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
       'stumped', 'hit wicket']

# %%
dismissal_col=df[df['dismissal_kind'].isin(dismissal_kinds)]
dismissal_col.head()
# Out:
#      match_id  inning                 batting_team  \
# 11          1       1          Sunrisers Hyderabad
# 64          1       1          Sunrisers Hyderabad
# 94          1       1          Sunrisers Hyderabad
# 116         1       1          Sunrisers Hyderabad
# 160         1       2  Royal Challengers Bangalore
#
#                     bowling_team  over  ball        batsman   non_striker  \
# 11   Royal Challengers Bangalore     2     5      DA Warner      S Dhawan
# 64   Royal Challengers Bangalore    11     3       S Dhawan  MC Henriques
# 94   Royal Challengers Bangalore    16     2   MC Henriques  Yuvraj Singh
# 116  Royal Challengers Bangalore    19     4   Yuvraj Singh      DJ Hooda
# 160          Sunrisers Hyderabad     6     4  Mandeep Singh      CH Gayle
#
#           bowler  is_super_over  ...  bye_runs  legbye_runs  noball_runs  \
# 11   A Choudhary              0  ...         0            0            0
# ...

# %%
dismissal_col['bowler'].value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>
